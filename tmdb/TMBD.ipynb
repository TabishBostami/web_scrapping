# %%
import requests
import pandas as pd

# %%
responce = requests.get('https://api.themoviedb.org/3/movie/popular?api_key=e357c47af5cfc3005a4e288e4e5c7cbf&language=en-US&page=1').json()

# %%
final = pd.DataFrame()

for j in range(1,500):
    responce = requests.get('https://api.themoviedb.org/3/movie/popular?api_key=e357c47af5cfc3005a4e288e4e5c7cbf&language=en-US&page={}'.format(j)).json()
    popularity = []
    vote_count = []
    original_language = []
    title = []
    vote_average= []
    overview = []
    release_date = []

    for i in responce['results']:
        try:

            popularity.append(i['popularity'])
            vote_count.append(i['vote_count'])
            original_language.append(i['original_language'])
            title.append(i['title'])
            vote_average.append(i['vote_average'])
            overview.append(i['overview'])
            release_date.append(i['release_date'])
        except KeyError:
            continue

    c = {'title':title,'overview':overview,'original_language':original_language,'popularity':popularity,'release_date':release_date,'popularity':popularity,'vote_average':vote_average}
    try:
        df = pd.DataFrame(c)
    

        final = pd.concat([final, df], axis=0,ignore_index=True)
    except ValueError:
        continue

# %%
final
# Out:
#                                  title  \
# 0              Insidious: The Red Door
# 1                    Meg 2: The Trench
# 2                               Barbie
# 3                            The Flash
# 4     Transformers: Rise of the Beasts
# ...                                ...
# 9815           Josie and the Pussycats
# 9816                          Hounddog
# 9817             The Constant Gardener
# 9818               The Death of Stalin
# 9819       Gayniggers from Outer Space
#
#                                                overview original_language  \
# 0     To put their demons to rest once and for all, ...                en
# 1     An exploratory dive into the deepest depths of...                en
# 2     Barbie and Ken are having the time of their li...                en
# 3     When his attempt to save his family inadverten...                en
# 4     When a new threat capable of destroying the en...                en
# ...                                                 ...               ...
# 9815  Josie, Melody and Val are three small-town gir...                en
# 9816  A drama set in the American South, where a pre...                en
# 9817  Justin Quayle is a low-level British diplomat ...                en
# 9818  When dictator Joseph Stalin dies, his parasiti...                en
# 9819  Extraterrestrial beings travel the galaxy to f...                en
#
#       popularity release_date  vote_average
# 0       3445.105   2023-07-05           6.8
# 1       3190.991   2023-08-02           6.9
# 2       3087.959   2023-07-19           7.5
# 3       3042.058   2023-06-13           7.0
# 4       2811.657   2023-06-06           7.5
# ...          ...          ...           ...
# 9815      12.311   2001-04-06           5.5
# 9816      12.311   2007-01-22           6.1
# 9817      12.310   2005-08-31           7.0
# 9818      12.307   2017-10-20           7.0
# 9819      12.306   1992-01-01           4.3
#
# [9820 rows x 6 columns]

# %%
final.head(30)
# Out:
#                                                 title  \
# 0                             Insidious: The Red Door
# 1                                   Meg 2: The Trench
# 2                                              Barbie
# 3                                           The Flash
# 4                    Transformers: Rise of the Beasts
# 5                                       Hidden Strike
# 6                                  The Little Mermaid
# 7                         Resident Evil: Death Island
# 8                                              Fast X
# 9                      Guardians of the Galaxy Vol. 3
# 10          Miraculous: Ladybug & Cat Noir, The Movie
# 11                                   Shin Kamen Rider
# 12                                     Fear the Night
# 13                       Ruby Gillman, Teenage Kraken
# 14                Spider-Man: Across the Spider-Verse
# 15                           Justice League: Warworld
# 16                             Mavka: The Forest Song
# 17                                       Warhorse One
# 18  The Venture Bros.: Radiant is the Blood of the...
# 19                                            The Meg
# 20                                        Oppenheimer
# 21                                          The Flood
# 22                        The Super Mario Bros. Movie
# 23                               John Wick: Chapter 4
# 24                       Kingdom 3: The Flame of Fate
# 25                                          Elemental
# 26                              Knights of the Zodiac
# 27                        La Leyenda de los Chaneques
# 28                                      Jericho Ridge
# 29                                   Sound of Freedom
#
#                                              overview original_language  \
# 0   To put their demons to rest once and for all, ...                en
# 1   An exploratory dive into the deepest depths of...                en
# 2   Barbie and Ken are having the time of their li...                en
# 3   When his attempt to save his family inadverten...                en
# 4   When a new threat capable of destroying the en...                en
# 5   Two elite soldiers must escort civilians throu...                en
# 6   The youngest of King Triton’s daughters, and t...                en
# 7   In San Francisco, Jill Valentine is dealing wi...                ja
# 8   Over many missions and against impossible odds...                en
# 9   Peter Quill, still reeling from the loss of Ga...                en
# 10  A life of an ordinary Parisian teenager Marine...                fr
# 11  A man forced to bear power and stripped of hum...                ja
# 12  During a bachelorette party in a secluded Cali...                en
# 13  Ruby Gillman, a sweet and awkward high school ...                en
# 14  After reuniting with Gwen Stacy, Brooklyn’s fu...                en
# 15  Until now, the Justice League has been a loose...                en
# 16  Mavka — a Soul of the Forest and its Warden — ...                uk
# 17  A gunned down Navy SEAL Master Chief must guid...                en
# 18  A nationwide manhunt for Hank Venture leads to...                en
# 19  A deep sea submersible pilot revisits his past...                en
# 20  The story of J. Robert Oppenheimer’s role in t...                en
# 21  A horde of giant hungry alligators is unleashe...                en
# 22  While working underground to fix a water main,...                en
# 23  With the price on his head ever increasing, Jo...                en
# 24  It follows Li Xin and Wang Qi as they stand on...                ja
# 25  In a city where fire, water, land and air resi...                en
# 26  When a headstrong street orphan, Seiya, in sea...                en
# 27  Five years after giving up his powers and sepa...                es
# 28  North Washington county sheriff Tabby finds he...                en
# 29  The story of Tim Ballard, a former US governme...                en
#
#     popularity release_date  vote_average
# 0     3445.105   2023-07-05           6.8
# 1     3190.991   2023-08-02           6.9
# 2     3087.959   2023-07-19           7.5
# 3     3042.058   2023-06-13           7.0
# 4     2811.657   2023-06-06           7.5
# 5     2371.921   2023-07-06           7.2
# 6     2133.210   2023-05-18           6.5
# 7     1866.304   2023-06-22           7.9
# 8     1701.769   2023-05-17           7.3
# 9     1641.321   2023-05-03           8.1
# 10    1586.269   2023-07-05           8.0
# 11    1438.343   2023-03-17           7.7
# 12    1411.722   2023-07-21           6.2
# 13    1352.807   2023-06-28           7.7
# 14    1309.783   2023-05-31           8.4
# 15    1303.369   2023-07-25           7.6
# 16    1219.757   2023-03-02           7.4
# 17    1122.383   2023-06-30           7.4
# 18    1083.741   2023-07-21           7.7
# 19    1066.747   2018-08-09           6.2
# 20     980.538   2023-07-19           8.3
# 21     973.125   2023-07-14           6.2
# 22     954.674   2023-04-05           7.8
# 23     938.494   2023-03-22           7.8
# 24     914.141   2023-07-28           8.4
# 25     879.355   2023-06-14           7.6
# 26     856.911   2023-04-27           6.7
# 27     762.905   2023-07-14           8.7
# 28     762.729   2023-07-14           6.0
# 29     678.213   2023-07-03           8.1
